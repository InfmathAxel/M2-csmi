# %% [markdown]
# # Distributions univariées et multivariées

# %%
import openturns as ot

# %% [markdown]
# ## Exercice 1 : loi Beta
#
# - Créer une distribution `Beta` de paramètres suivants :
#   - $\alpha=5$ : premier paramètre de forme,
#   - $\beta=2$ : second paramètre de forme,
#   - $a=9$ : borne inférieure,
#   - $b=10$ : borne supérieure
# - Dessiner la PDF, la CDF
# - Quelle méthode de l'objet permet de savoir si cette distribution est continue ?

# %% [markdown]
# ## Solution de l'exercice 1 : loi beta

# %%
myBeta = ot.Beta(5, 2, 9, 10)
myBeta.isContinuous()
# Out:
# True

# %%
myBeta.drawPDF()
# Out:
# class=Graph name=pdf as a function of X0 implementation=class=GraphImplementation name=pdf as a function of X0 title= xTitle=X0 yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=X0 PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[9.0916,0.00191818],[9.10127,0.00283556],[9.11094,0.00404033],[9.12061,0.00558325],[9.13029,0.00751788],[9.13996,0.0099003],[9.14963,0.0127888],[9.15931,0.0162435],[9.16898,0.0203261],[9.17865,0.0250998],[9.18832,0.0306284],[9.198,0.0369767],[9.20767,0.0442098],[9.21734,0.0523926],[9.22702,0.0615902],[9.23669,0.0718669],[9.24636,0.083286],[9.25603,0.0959099],[9.26571,0.1098],[9.27538,0.125014],[9.28505,0.14161],[9.29473,0.159643],[9.3044,0.179164],[9.31407,0.200222],[9.32374,0.222863],[9.33342,0.24713],[9.34309,0.27306],[9.35276,0.300687],[9.36244,0.330041],[9.37211,0.361146],[9.38178,0.394022],[9.39145,0.428684],[9.40113,0.465139],[9.4108,0.50339],[9.42047,0.543433],[9.43015,0.585257],[9.43982,0.628844],[9.44949,0.674171],[9.45916,0.721204],[9.46884,0.769903],[9.47851,0.82022],[9.48818,0.872098],[9.49786,0.925471],[9.50753,0.980265],[9.5172,1.0364],[9.52687,1.09377],[9.53655,1.15228],[9.54622,1.21182],[9.55589,1.27225],[9.56557,1.33345],[9.57524,1.39527],[9.58491,1.45755],[9.59458,1.52011],[9.60426,1.58278],[9.61393,1.64537],[9.6236,1.70765],[9.63328,1.76942],[9.64295,1.83045],[9.65262,1.89047],[9.66229,1.94923],[9.67197,2.00646],[9.68164,2.06186],[9.69131,2.11514],[9.70099,2.16596],[9.71066,2.21399],[9.72033,2.25889],[9.73,2.30027],[9.73968,2.33777],[9.74935,2.37098],[9.75902,2.39948],[9.7687,2.42283],[9.77837,2.44058],[9.78804,2.45227],[9.79771,2.4574],[9.80739,2.45547],[9.81706,2.44594],[9.82673,2.42828],[9.83641,2.40191],[9.84608,2.36626],[9.85575,2.32072],[9.86542,2.26467],[9.8751,2.19745],[9.88477,2.1184],[9.89444,2.02684],[9.90412,1.92205],[9.91379,1.8033],[9.92346,1.66985],[9.93313,1.5209],[9.94281,1.35567],[9.95248,1.17333],[9.96215,0.973038],[9.97183,0.753922],[9.9815,0.51509],[9.99117,0.255624],[10.0008,0],[10.0105,0],[10.0202,0],[10.0299,0],[10.0395,0],[10.0492,0],[10.0589,0],[10.0686,0],[10.0782,0],[10.0879,0],[10.0976,0],[10.1072,0],[10.1169,0],[10.1266,0],[10.1363,0],[10.1459,0],[10.1556,0],[10.1653,0],[10.175,0],[10.1846,0],[10.1943,0],[10.204,0],[10.2136,0],[10.2233,0],[10.233,0],[10.2427,0],[10.2523,0],[10.262,0],[10.2717,0],[10.2814,0],[10.291,0],[10.3007,0],[10.3104,0],[10.32,0],[10.3297,0]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %%
myBeta.drawCDF()
# Out:
# class=Graph name=cdf as a function of X0 implementation=class=GraphImplementation name=cdf as a function of X0 title= xTitle=X0 yTitle=CDF axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=X0 CDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[9.0916,3.57297e-05],[9.10127,5.85089e-05],[9.11094,9.1512e-05],[9.12061,0.000137762],[9.13029,0.000200787],[9.13996,0.000284645],[9.14963,0.000393947],[9.15931,0.000533878],[9.16898,0.000710213],[9.17865,0.00092933],[9.18832,0.00119822],[9.198,0.0015245],[9.20767,0.00191641],[9.21734,0.00238283],[9.22702,0.00293326],[9.23669,0.00357782],[9.24636,0.00432726],[9.25603,0.00519293],[9.26571,0.00618679],[9.27538,0.00732136],[9.28505,0.00860973],[9.29473,0.0100655],[9.3044,0.0117029],[9.31407,0.0135365],[9.32374,0.0155815],[9.33342,0.0178532],[9.34309,0.0203677],[9.35276,0.0231413],[9.36244,0.0261903],[9.37211,0.0295318],[9.38178,0.0331827],[9.39145,0.0371602],[9.40113,0.0414817],[9.4108,0.0461644],[9.42047,0.0512259],[9.43015,0.0566833],[9.43982,0.0625538],[9.44949,0.0688543],[9.45916,0.0756016],[9.46884,0.0828119],[9.47851,0.0905012],[9.48818,0.0986847],[9.49786,0.107377],[9.50753,0.116593],[9.5172,0.126346],[9.52687,0.136647],[9.53655,0.147509],[9.54622,0.158942],[9.55589,0.170955],[9.56557,0.183557],[9.57524,0.196754],[9.58491,0.210551],[9.59458,0.224952],[9.60426,0.239959],[9.61393,0.255572],[9.6236,0.271789],[9.63328,0.288606],[9.64295,0.306017],[9.65262,0.324014],[9.66229,0.342586],[9.67197,0.361719],[9.68164,0.381396],[9.69131,0.4016],[9.70099,0.422307],[9.71066,0.443493],[9.72033,0.465128],[9.73,0.487181],[9.73968,0.509616],[9.74935,0.532394],[9.75902,0.555469],[9.7687,0.578797],[9.77837,0.602323],[9.78804,0.625992],[9.79771,0.649743],[9.80739,0.673509],[9.81706,0.697221],[9.82673,0.720802],[9.83641,0.74417],[9.84608,0.767238],[9.85575,0.789915],[9.86542,0.812101],[9.8751,0.833691],[9.88477,0.854574],[9.89444,0.874632],[9.90412,0.893742],[9.91379,0.911771],[9.92346,0.928581],[9.93313,0.944025],[9.94281,0.957951],[9.95248,0.970196],[9.96215,0.980592],[9.97183,0.98896],[9.9815,0.995114],[9.99117,0.998858],[10.0008,1],[10.0105,1],[10.0202,1],[10.0299,1],[10.0395,1],[10.0492,1],[10.0589,1],[10.0686,1],[10.0782,1],[10.0879,1],[10.0976,1],[10.1072,1],[10.1169,1],[10.1266,1],[10.1363,1],[10.1459,1],[10.1556,1],[10.1653,1],[10.175,1],[10.1846,1],[10.1943,1],[10.204,1],[10.2136,1],[10.2233,1],[10.233,1],[10.2427,1],[10.2523,1],[10.262,1],[10.2717,1],[10.2814,1],[10.291,1],[10.3007,1],[10.3104,1],[10.32,1],[10.3297,1]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %% [markdown]
# ## Exercice 2 : loi exponentielle
#
# - Créer une variable `Exponential` de moyenne $\lambda=3$.
# - Dessiner la PDF, la CDF
# - Est-elle continue ?

# %% [markdown]
# ## Solution de l'exercice 2 : loi exponentielle
#
# On remarque que la loi exponentielle d'OpenTURNS peut utiliser un paramètre de localisation $\gamma$ (par défaut $\gamma=0)$.

# %%
myExponential = ot.Exponential(3)
myExponential.isContinuous()
# Out:
# True

# %%
myExponential.drawPDF()
# Out:
# class=Graph name=pdf as a function of X0 implementation=class=GraphImplementation name=pdf as a function of X0 title= xTitle=X0 yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=X0 PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[-0.697487,0],[-0.681226,0],[-0.664964,0],[-0.648702,0],[-0.63244,0],[-0.616178,0],[-0.599916,0],[-0.583654,0],[-0.567392,0],[-0.551131,0],[-0.534869,0],[-0.518607,0],[-0.502345,0],[-0.486083,0],[-0.469821,0],[-0.453559,0],[-0.437297,0],[-0.421035,0],[-0.404774,0],[-0.388512,0],[-0.37225,0],[-0.355988,0],[-0.339726,0],[-0.323464,0],[-0.307202,0],[-0.29094,0],[-0.274678,0],[-0.258417,0],[-0.242155,0],[-0.225893,0],[-0.209631,0],[-0.193369,0],[-0.177107,0],[-0.160845,0],[-0.144583,0],[-0.128322,0],[-0.11206,0],[-0.0957977,0],[-0.0795359,0],[-0.063274,0],[-0.0470121,0],[-0.0307502,0],[-0.0144883,0],[0.00177357,2.98408],[0.0180355,2.84199],[0.0342973,2.70667],[0.0505592,2.5778],[0.0668211,2.45505],[0.083083,2.33816],[0.0993449,2.22683],[0.115607,2.1208],[0.131869,2.01982],[0.148131,1.92364],[0.164392,1.83205],[0.180654,1.74482],[0.196916,1.66174],[0.213178,1.58261],[0.22944,1.50726],[0.245702,1.43549],[0.261964,1.36714],[0.278226,1.30204],[0.294487,1.24005],[0.310749,1.181],[0.327011,1.12477],[0.343273,1.07121],[0.359535,1.02021],[0.375797,0.971632],[0.392059,0.925368],[0.408321,0.881307],[0.424583,0.839343],[0.440844,0.799378],[0.457106,0.761316],[0.473368,0.725066],[0.48963,0.690542],[0.505892,0.657662],[0.522154,0.626348],[0.538416,0.596524],[0.554678,0.568121],[0.57094,0.54107],[0.587201,0.515307],[0.603463,0.490771],[0.619725,0.467403],[0.635987,0.445148],[0.652249,0.423952],[0.668511,0.403766],[0.684773,0.384541],[0.701035,0.366231],[0.717297,0.348793],[0.733558,0.332185],[0.74982,0.316368],[0.766082,0.301304],[0.782344,0.286958],[0.798606,0.273294],[0.814868,0.260282],[0.83113,0.247888],[0.847392,0.236085],[0.863653,0.224844],[0.879915,0.214138],[0.896177,0.203942],[0.912439,0.194231],[0.928701,0.184983],[0.944963,0.176175],[0.961225,0.167787],[0.977487,0.159798],[0.993749,0.152189],[1.01001,0.144942],[1.02627,0.138041],[1.04253,0.131468],[1.0588,0.125208],[1.07506,0.119247],[1.09132,0.113569],[1.10758,0.108161],[1.12384,0.103011],[1.14011,0.0981062],[1.15637,0.0934349],[1.17263,0.0889861],[1.18889,0.084749],[1.20515,0.0807137],[1.22141,0.0768705],[1.23768,0.0732104],[1.25394,0.0697245],[1.2702,0.0664046],[1.28646,0.0632427],[1.30272,0.0602314],[1.31899,0.0573635],[1.33525,0.0546322],[1.35151,0.0520309],[1.36777,0.0495534],[1.38403,0.047194]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %%
myExponential.drawCDF()
# Out:
# class=Graph name=cdf as a function of X0 implementation=class=GraphImplementation name=cdf as a function of X0 title= xTitle=X0 yTitle=CDF axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=X0 CDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[-0.697487,0],[-0.681226,0],[-0.664964,0],[-0.648702,0],[-0.63244,0],[-0.616178,0],[-0.599916,0],[-0.583654,0],[-0.567392,0],[-0.551131,0],[-0.534869,0],[-0.518607,0],[-0.502345,0],[-0.486083,0],[-0.469821,0],[-0.453559,0],[-0.437297,0],[-0.421035,0],[-0.404774,0],[-0.388512,0],[-0.37225,0],[-0.355988,0],[-0.339726,0],[-0.323464,0],[-0.307202,0],[-0.29094,0],[-0.274678,0],[-0.258417,0],[-0.242155,0],[-0.225893,0],[-0.209631,0],[-0.193369,0],[-0.177107,0],[-0.160845,0],[-0.144583,0],[-0.128322,0],[-0.11206,0],[-0.0957977,0],[-0.0795359,0],[-0.063274,0],[-0.0470121,0],[-0.0307502,0],[-0.0144883,0],[0.00177357,0.00530658],[0.0180355,0.0526687],[0.0342973,0.0977756],[0.0505592,0.140735],[0.0668211,0.181648],[0.083083,0.220614],[0.0993449,0.257724],[0.115607,0.293068],[0.131869,0.326728],[0.148131,0.358786],[0.164392,0.389317],[0.180654,0.418395],[0.196916,0.446088],[0.213178,0.472462],[0.22944,0.497581],[0.245702,0.521503],[0.261964,0.544287],[0.278226,0.565985],[0.294487,0.586651],[0.310749,0.606332],[0.327011,0.625077],[0.343273,0.642929],[0.359535,0.65993],[0.375797,0.676123],[0.392059,0.691544],[0.408321,0.706231],[0.424583,0.720219],[0.440844,0.733541],[0.457106,0.746228],[0.473368,0.758311],[0.48963,0.769819],[0.505892,0.780779],[0.522154,0.791217],[0.538416,0.801159],[0.554678,0.810626],[0.57094,0.819643],[0.587201,0.828231],[0.603463,0.83641],[0.619725,0.844199],[0.635987,0.851617],[0.652249,0.858683],[0.668511,0.865411],[0.684773,0.87182],[0.701035,0.877923],[0.717297,0.883736],[0.733558,0.889272],[0.74982,0.894544],[0.766082,0.899565],[0.782344,0.904347],[0.798606,0.908902],[0.814868,0.913239],[0.83113,0.917371],[0.847392,0.921305],[0.863653,0.925052],[0.879915,0.928621],[0.896177,0.932019],[0.912439,0.935256],[0.928701,0.938339],[0.944963,0.941275],[0.961225,0.944071],[0.977487,0.946734],[0.993749,0.94927],[1.01001,0.951686],[1.02627,0.953986],[1.04253,0.956177],[1.0588,0.958264],[1.07506,0.960251],[1.09132,0.962144],[1.10758,0.963946],[1.12384,0.965663],[1.14011,0.967298],[1.15637,0.968855],[1.17263,0.970338],[1.18889,0.97175],[1.20515,0.973095],[1.22141,0.974376],[1.23768,0.975597],[1.25394,0.976759],[1.2702,0.977865],[1.28646,0.978919],[1.30272,0.979923],[1.31899,0.980879],[1.33525,0.981789],[1.35151,0.982656],[1.36777,0.983482],[1.38403,0.984269]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %% [markdown]
# ## Exercice 3 : une variable de Bernoulli
#
# - Créer une variable de Bernoulli telle que :
#
# \begin{align*}
# P(X=1)&=0.7 \\
# P(X=0)&=0.3
# \end{align*}
#
# En d'autres termes, créer une variable de Bernoulli de paramètre $p=0.7$
#
# - Dessiner la PDF
# - Quel est son support ?

# %% [markdown]
# ## Solution de l'exercice 3 : une variable de Bernoulli

# %%
u = ot.Bernoulli(0.7)
u.getSupport()
# Out:
# class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=1 data=[[0],[1]]

# %%
u.drawPDF()
# Out:
# class=Graph name=X0 PDF implementation=class=GraphImplementation name=X0 PDF title=X0 PDF xTitle=X0 yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=X0 PDF implementation=class=Curve name=X0 PDF derived from class=DrawableImplementation name=X0 PDF legend=X0 PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=8 dimension=2 data=[[-1,0],[0,0],[0,0.3],[0,0],[1,0],[1,0.7],[1,0],[2,0]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %%
u.isContinuous()
# Out:
# False

# %% [markdown]
# ## Exercice 4 : défaillance de disques
#
# Les disques d'une certaine société sont défectueux avec une probabilité égale à 0.01. On fait l'hypothèse que les défaillances sont indépendances entre deux disques.
#
# La société vend les disques par lots de 10 et offre une garantie de remboursement si plus d'un disque est défectueux dans le lot.
# - Quelle est la probabilité d'avoir un retour de lot ?
# - Si on achète trois lots, quelle est la probabilité que exactement un lot soit retourné ?

# %% [markdown]
# ## Solution de l'exercice 4 : défaillance de disques
#
# Sheldon Ross, Introduction to probability and statistics, 3d Ed., Elsevier, 2004
#
# If X is the number of defective disks in a package, then assuming that customers always take advantage of the guarantee, it follows that X is a binomial random variable with parameters (10, .01). Hence the probability that a package will have to be replaced is $p = P(X>1) = 0.004266$.

# %%
defectbino = ot.Binomial(10,0.01)
defectbino.drawPDF()
# Out:
# class=Graph name=X0 PDF implementation=class=GraphImplementation name=X0 PDF title=X0 PDF xTitle=X0 yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=X0 PDF implementation=class=Curve name=X0 PDF derived from class=DrawableImplementation name=X0 PDF legend=X0 PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=8 dimension=2 data=[[-1,0],[0,0],[0,0.904382],[0,0],[1,0],[1,0.0913517],[1,0],[1,0]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %%
p = defectbino.computeComplementaryCDF(1)
p
# Out:
# 0.004266200242831419

# %% [markdown]
# Because each package will, independently, have to be replaced with probability p, it follows from the law of large numbers that, in the long run, p percent of the packages will have to be replaced.
#
# It follows from the foregoing that the number of packages that the person will have to return is a binomial random variable with parameters n = 3 and p. Therefore, the probability that exactly one of the three packages will be returned is 0.01269.

# %%
returnbino = ot.Binomial(3,p)
returnbino.computePDF(1)
# Out:
# 0.012689630881901

# %% [markdown]
# ## Exercice 5 : pluviosité à Los Angeles
#
# Les données du "National Oceanic and Atmospheric Administration" indiquent que le cumul de précipitations pour une année à Los Angeles suit une loi gaussienne de moyenne 12.08 pouces et d'écart-type 3.1 pouces.
#
# Dans cet exercice, on fait l'hypothèse que les cumuls de précipitations entre deux années sont indépendants.
#
# - Calculer la probabilité d'observer un cumul annuel supérieur à 15 pouces.
# - Calculer la probabilité que le cumul de précipitations pendant deux ans soit supérieur à 25 pouces.
# - Calculer la probabilité que la différence de cumul entre deux années soit supérieure à 3 pouces.

# %% [markdown]
# ## Solution de l'exercice 5 : pluviosité à Los Angeles
#
# Sheldon Ross, Introduction to probability and statistics, 3d Ed., Elsevier, 2004
#
# Soit X la variable aléatoire correspondant à la précipitation annuelle en pouces. Par hypothèse, la variable $X$ est une variable gaussienne de moyenne 12.08 et d'écart-type 3.1. La probabilité d'observer une précipitation supérieure à 15 pouces est $P(X>15) = 0.1731$.

# %%
x = ot.Normal(12.08,3.1)
x.drawPDF()
# Out:
# class=Graph name=pdf as a function of X0 implementation=class=GraphImplementation name=pdf as a function of X0 title= xTitle=X0 yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=X0 PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[0.513403,0.000122045],[0.694131,0.000151444],[0.87486,0.000187287],[1.05559,0.000230827],[1.23632,0.000283524],[1.41704,0.000347071],[1.59777,0.000423418],[1.7785,0.000514806],[1.95923,0.000623796],[2.13996,0.000753296],[2.32068,0.000906593],[2.50141,0.00108738],[2.68214,0.0012998],[2.86287,0.00154845],[3.0436,0.00183839],[3.22432,0.00217523],[3.40505,0.00256505],[3.58578,0.00301446],[3.76651,0.00353059],[3.94724,0.00412107],[4.12796,0.00479397],[4.30869,0.00555783],[4.48942,0.00642154],[4.67015,0.00739429],[4.85088,0.00848552],[5.03161,0.00970474],[5.21233,0.0110615],[5.39306,0.0125651],[5.57379,0.0142247],[5.75452,0.0160489],[5.93525,0.0180455],[6.11597,0.0202217],[6.2967,0.0225835],[6.47743,0.0251355],[6.65816,0.027881],[6.83889,0.0308215],[7.01961,0.0339564],[7.20034,0.0372833],[7.38107,0.0407972],[7.5618,0.0444909],[7.74253,0.0483543],[7.92325,0.0523749],[8.10398,0.0565373],[8.28471,0.0608234],[8.46544,0.0652125],[8.64617,0.069681],[8.82689,0.0742031],[9.00762,0.0787506],[9.18835,0.0832931],[9.36908,0.0877988],[9.54981,0.0922342],[9.73054,0.0965648],[9.91126,0.100756],[10.092,0.104772],[10.2727,0.108579],[10.4534,0.112142],[10.6342,0.115429],[10.8149,0.118409],[10.9956,0.121054],[11.1764,0.123338],[11.3571,0.125239],[11.5378,0.126738],[11.7185,0.127819],[11.8993,0.128473],[12.08,0.128691],[12.2607,0.128473],[12.4415,0.127819],[12.6222,0.126738],[12.8029,0.125239],[12.9836,0.123338],[13.1644,0.121054],[13.3451,0.118409],[13.5258,0.115429],[13.7066,0.112142],[13.8873,0.108579],[14.068,0.104772],[14.2487,0.100756],[14.4295,0.0965648],[14.6102,0.0922342],[14.7909,0.0877988],[14.9716,0.0832931],[15.1524,0.0787506],[15.3331,0.0742031],[15.5138,0.069681],[15.6946,0.0652125],[15.8753,0.0608234],[16.056,0.0565373],[16.2367,0.0523749],[16.4175,0.0483543],[16.5982,0.0444909],[16.7789,0.0407972],[16.9597,0.0372833],[17.1404,0.0339564],[17.3211,0.0308215],[17.5018,0.027881],[17.6826,0.0251355],[17.8633,0.0225835],[18.044,0.0202217],[18.2248,0.0180455],[18.4055,0.0160489],[18.5862,0.0142247],[18.7669,0.0125651],[18.9477,0.0110615],[19.1284,0.00970474],[19.3091,0.00848552],[19.4899,0.00739429],[19.6706,0.00642154],[19.8513,0.00555783],[20.032,0.00479397],[20.2128,0.00412107],[20.3935,0.00353059],[20.5742,0.00301446],[20.7549,0.00256505],[20.9357,0.00217523],[21.1164,0.00183839],[21.2971,0.00154845],[21.4779,0.0012998],[21.6586,0.00108738],[21.8393,0.000906593],[22.02,0.000753296],[22.2008,0.000623796],[22.3815,0.000514806],[22.5622,0.000423418],[22.743,0.000347071],[22.9237,0.000283524],[23.1044,0.000230827],[23.2851,0.000187287],[23.4659,0.000151444],[23.6466,0.000122045]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %%
x.computeComplementaryCDF(15.)
# Out:
# 0.17311283588095566

# %% [markdown]
# Let $X_1$ and $X_2$ be the precipitation totals for the next 2 years. La variable aléatoire associée à la précipitation cumulée sur deux années est donc $Y = X_1 + X_2$. On souhaite calculer $P(X_1 + X_2 > 25)$.

# %% [markdown]
# Nous pouvons directement utiliser l'arithmétique des distributions.

# %%
y = x + x
y.computeComplementaryCDF(25)
# Out:
# 0.4240265461378832

# %% [markdown]
# On obtient $P(X_1 + X_2 > 25) = 0.4240$.

# %% [markdown]
# Le texte de Ross est fondé sur le calcul suivant. On suppose que
#
# $$
# E(X_1) = E(X_2) = \mu
# $$
#
# et
#
# $$
# V(X_1) = V(X_2) = \sigma^2
# $$
#
# où $\mu$ et $\sigma$ sont la moyenne et l'écart-type des variables gaussiennes $X_1$ et $X_2$.
#
# Les propriétés de la loi gaussienne impliquent que la moyenne et la variance sont :
#
# \begin{align*}
# E(Y) &= E(X_1 + X_2)= E(X_1) + E(X_2) = 2\mu \\
# V(Y) &= V(X_1 + X_2)= V(X_1) + V(X_2) = 2\sigma^2,
# \end{align*}
#
# où la seconde égalité est justifiée par le faite que les variables sont indépendantes.

# %%
import numpy as np
muX = 12.08
sigmaX = 3.1
varianceX = sigmaX**2
muY = 2*muX
varianceY = 2 * varianceX
sigmaY = np.sqrt(varianceY)
print("muY = %f, sigmaY = %f" % (muY,sigmaY))
# Out:
# muY = 24.160000, sigmaY = 4.384062

# %%
y.getMean()
# Out:
# class=Point name=Unnamed dimension=1 values=[24.16]

# %%
y.getStandardDeviation()
# Out:
# class=Point name=Unnamed dimension=1 values=[4.38406]

# %%
y = ot.Normal(muY,sigmaY)
y.computeComplementaryCDF(25)
# Out:
# 0.4240265461378832

# %% [markdown]
# On souhaite calculer la probabilité $P(X_1 > X_2 + 3)$. On a :
#
# $$
# P(X_1 > X_2 + 3) = P(X_1 - X_2 > 3)
# $$
#
# On considère alors la variable
#
# $$
# Z = X_1 - X_2.
# $$
#
# Les propriétés de la loi gaussienne impliquent que la moyenne et la variance sont :
#
# \begin{align*}
# E(Z) &= E(X_1 - X_2) = E(X_1) - E(X_2) = 0 \\
# V(Z) &= V(X_1 - X_2) = V(X_1) + V(X_2) = 2\sigma^2,
# \end{align*}
#
# où la seconde égalité est justifiée par le faite que les variables sont indépendantes.

# %% [markdown]
# Dans le script suivant, nous utilisons l'arithmétique des distributions.

# %%
z = x - x
z.computeComplementaryCDF(3.)
# Out:
# 0.24689385678434955

# %% [markdown]
# On en conclut que $P(X_1>X_2 + 3) = 0.2469$.
#
# Pour vérifier le calcul, on utilise le script suivant qui repose sur les équations précédentes.

# %%
muX = 12.08
sigmaX = 3.1
varianceX = sigmaX**2
muZ = 0
varianceZ = 2 * varianceX
sigmaZ = np.sqrt(varianceY)
print("muZ = %f, sigmaZ = %f" % (muZ,sigmaZ))
# Out:
# muZ = 0.000000, sigmaZ = 4.384062

# %%
z.getMean()
# Out:
# class=Point name=Unnamed dimension=1 values=[0]

# %%
z.getStandardDeviation()
# Out:
# class=Point name=Unnamed dimension=1 values=[4.38406]

# %%
z = ot.Normal(muZ,sigmaZ)
z.computeComplementaryCDF(3.)
# Out:
# 0.24689385678434955

# %% [markdown]
# On observe que l'on obtient la même probabilité que précédemment.

# %% [markdown]
# ## Exercice 6 : taille des hommes
#
# Références :
# - [1] Statistical Abstract of the United States U.S. Census Bureau. Table 209. Cumulative percent distribution
# of population by height and sex : 2007-2008, 2012. https://www.census.gov/compendia/statab/2012/tables/12s0209.pdf
# - [2] Mark F. Schilling, Ann E. Watkins, and William Watkins. Is human height bimodal ? The American
# Statistician, American Statistical Association, 56(3) :223–229, 2002.
#
# Le bureau de recensement des Etats-Unis fournit des statistiques sur ce pays. La table 209 dans [1] présente la distribution de la population par taille et par sexe. Bien que la question soit controversée [2], on pense que la distribution de la taille des hommes suit approximativement la loi Gaussienne.
#
# Soit X la taille d’un homme dont l’âge est entre 20 et 79 ans D’après les données dans [1], on peut
# estimer que la moyenne et l’écart-type sont $\mu = 1.7633$ (m) et $\sigma = 0.0680$ (m).
#
# - Quelle est la probabilité que la taille d’un homme soit inférieure à 2 mètres ? Quelle est la probabilité d'avoir une taille supérieure à 2 mètres ?
# - Quel est le quantile de niveau $p=0.99$ ? Quel est son sens physique ?

# %% [markdown]
# ## Solution de l'exercice 6 : taille des hommes

# %% [markdown]
# On commence par définir la variable aléatoire associée à la taille des hommes.

# %%
x = ot.Normal(1.7633,0.0680)

# %% [markdown]
# Puis on calcule la probabilité $P(X<2)$.

# %%
x.computeCDF(2.)
# Out:
# 0.9997501175235604

# %% [markdown]
# On calcule ensuite la probabilité $P(X>2)$.

# %%
x.computeComplementaryCDF(2.)
# Out:
# 0.00024988247643966554

# %% [markdown]
# On calcule enfin le quantile de niveau $p=0.99$.

# %%
x.computeQuantile(0.99)[0]
# Out:
# 1.9214916554347772

# %% [markdown]
# En d'autres termes,
# - la probabilité d'avoir une taille inférieure à 2 mètres est : $P(X<2)=0.9997$,
# - la probabilité d'avoir une taille supérieure à 2 mètres est : $P(X<2)=0.0002499$.
# - le quantile de niveau 0.99 est égal à 1.921 i.e. la probabilité d'avoir une taille inférieure à 1.921 mètres est égale à 0.99.

# %% [markdown]
# ## Exercice 7 : une loi gaussienne bidimensionnelle
#
# - Build a collection of marginals which includes two normal distributions $X \sim \mathcal{N}(0,1)$;
# - Create a ComposedDistribution using the previous collection only;
# - Create a ComposedDistribution using the previous collection and a `Copula` structure (independent);
# - Create a composedDistribution using the previous collection and a `Copula` structure (Normal copula with $\rho=0.6$);
# - Get a `Sample` of size $1000$; plot it.

# %% [markdown]
# ## Solution de l'exercice 7 : une loi gaussienne bidimensionnelle

# %% [markdown]
# On commence par créer une liste de deux variables gaussiennes.

# %%
coll = [ot.Normal(0, 1)] * 2

# %% [markdown]
# On créée ensuite une distribution multivariée dont les maginales sont gaussiennes et la copule indépendante.

# %%
ind_dist = ot.ComposedDistribution(coll)

# %% [markdown]
# Dans le script suivant, on rend explicite la copule indépendante.

# %%
independent_copula = ot.IndependentCopula(2)
dist = ot.ComposedDistribution(coll, independent_copula)

# %% [markdown]
# Dans le script suivant, on utilise une copule gaussienne.

# %%
R = ot.CorrelationMatrix(2)
R[0,1] = 0.6
normal_copula = ot.NormalCopula(R)
norm_cop_dist = ot.ComposedDistribution(coll, normal_copula)

# %% [markdown]
# Les instructions suivantes permettent de dessiner les isovaleurs des deux distributions.

# %%
ind_cop_pdf = ind_dist.drawPDF()
ind_cop_pdf.setLegends(["Ind.Cop"])
ind_cop_pdf.setColors(["red"])
norm_cop_pdf = norm_cop_dist.drawPDF()
norm_cop_pdf.setLegends(["Norm.Cop"])

# %% [markdown]
# Pour observer la distribution, on génère deux échantillons de taille 10000.

# %%
N = 10000
# Indépendant
ind_sample = dist.getSample(N)
graph1 = ot.Graph("","x0","x1",True)
cloud1 = ot.Cloud(ind_sample)
graph1.add(cloud1)
# Dépendance Gaussienne
norm_sample = norm_cop_dist.getSample(N)
graph2 = ot.Graph("","x0","x1",True)
cloud2 = ot.Cloud(norm_sample)
graph2.add(cloud2)

# %%
import pylab as plt
import openturns.viewer
fig = plt.figure(figsize=(12, 8))
ax_ind_pdf = fig.add_subplot(2, 2, 1)
_ = ot.viewer.View(ind_cop_pdf, figure=fig, axes=[ax_ind_pdf])
ax_norm_pdf = fig.add_subplot(2, 2, 2)
_ = ot.viewer.View(norm_cop_pdf, figure=fig, axes=[ax_norm_pdf])
ax_x_ind = fig.add_subplot(2, 2, 3)
_ = ot.viewer.View(graph1, figure=fig, axes=[ax_x_ind])
ax_x_norm = fig.add_subplot(2, 2, 4)
_ = ot.viewer.View(graph2, figure=fig, axes=[ax_x_norm])
